# %%
from dataclasses import dataclass


experiment_name = "EXP1.2.3"
task_tag = "exp1.2.3"

@dataclass
class S:
    gap_start_x: float
    gap_end_x: float


param_sets: list[S] = []

for p in param_sets:
    print(
        f"./convert-notebook.sh notebooks/experiment-1.ipynb \
            --name={experiment_name} \
            gap_start_x={p.gap_start_x} \
            gap_end_x={p.gap_end_x} \
            task_name={experiment_name}: x={p.gap_start_x}-{p.gap_end_x}"
    )
